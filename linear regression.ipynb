# %% [markdown]
# #Scikit learn

# %% [markdown]
# #Matlplot

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.viridis)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
import pandas as pd


# %matplotlib inline

# %%
X = np.linspace(-1,1,101)
noise = np.random.randn(X.shape[0])*0.1
plt.plot(X)

# %%
X
# Out:
# array([-1.  , -0.98, -0.96, -0.94, -0.92, -0.9 , -0.88, -0.86, -0.84,
#        -0.82, -0.8 , -0.78, -0.76, -0.74, -0.72, -0.7 , -0.68, -0.66,
#        -0.64, -0.62, -0.6 , -0.58, -0.56, -0.54, -0.52, -0.5 , -0.48,
#        -0.46, -0.44, -0.42, -0.4 , -0.38, -0.36, -0.34, -0.32, -0.3 ,
#        -0.28, -0.26, -0.24, -0.22, -0.2 , -0.18, -0.16, -0.14, -0.12,
#        -0.1 , -0.08, -0.06, -0.04, -0.02,  0.  ,  0.02,  0.04,  0.06,
#         0.08,  0.1 ,  0.12,  0.14,  0.16,  0.18,  0.2 ,  0.22,  0.24,
#         0.26,  0.28,  0.3 ,  0.32,  0.34,  0.36,  0.38,  0.4 ,  0.42,
#         0.44,  0.46,  0.48,  0.5 ,  0.52,  0.54,  0.56,  0.58,  0.6 ,
#         0.62,  0.64,  0.66,  0.68,  0.7 ,  0.72,  0.74,  0.76,  0.78,
#         0.8 ,  0.82,  0.84,  0.86,  0.88,  0.9 ,  0.92,  0.94,  0.96,
#         0.98,  1.  ])

# %%
pd.DataFrame(X)
# Out:
#         0
# 0   -1.00
# 1   -0.98
# 2   -0.96
# 3   -0.94
# 4   -0.92
# 5   -0.90
# 6   -0.88
# 7   -0.86
# 8   -0.84
# 9   -0.82
# 10  -0.80
# 11  -0.78
# 12  -0.76
# 13  -0.74
# 14  -0.72
# 15  -0.70
# 16  -0.68
# 17  -0.66
# 18  -0.64
# 19  -0.62
# 20  -0.60
# 21  -0.58
# 22  -0.56
# 23  -0.54
# 24  -0.52
# 25  -0.50
# 26  -0.48
# 27  -0.46
# 28  -0.44
# 29  -0.42
# ..    ...
# 71   0.42
# 72   0.44
# 73   0.46
# 74   0.48
# 75   0.50
# 76   0.52
# 77   0.54
# 78   0.56
# 79   0.58
# 80   0.60
# 81   0.62
# 82   0.64
# 83   0.66
# 84   0.68
# 85   0.70
# 86   0.72
# 87   0.74
# 88   0.76
# 89   0.78
# 90   0.80
# 91   0.82
# 92   0.84
# 93   0.86
# 94   0.88
# 95   0.90
# 96   0.92
# 97   0.94
# 98   0.96
# 99   0.98
# 100  1.00
#
# [101 rows x 1 columns]

# %%
Y=2*X + noise #y = mx+c
plt.plot(Y)

# %%
plt.plot(noise)

# %%
print noise
# Out:
# [ 0.11368011 -0.09896745 -0.10797143  0.110293   -0.02219239  0.04041196
#  -0.19338366 -0.03145333 -0.02165591 -0.01956699  0.05994058 -0.01995853
#   0.13526191 -0.17968619  0.07912815  0.0522957  -0.04289785 -0.00512956
#   0.00742219  0.06779729  0.18065208  0.08737288  0.18785365 -0.1318696
#  -0.14431124 -0.03091141  0.17976406 -0.09355985  0.04713707  0.04221704
#  -0.02760451  0.03101187 -0.02083804  0.14006792 -0.10899497  0.0371512
#  -0.04744595  0.17807325 -0.02764023  0.04157322 -0.04386565  0.04471453
#  -0.09899994  0.15903569  0.13275747  0.0368933   0.07370552 -0.07757796
#   0.10070326  0.04733875 -0.01173016 -0.09186926  0.05309613  0.11008914
#   0.08954724 -0.07681971 -0.12520046 -0.03443557 -0.011434   -0.1339062
#  -0.22718602 -0.00701819 -0.143993   -0.02900617  0.07892388 -0.04675849
#   0.06007597 -0.18091655  0.06891584 -0.11154721  0.09256419  0.13395229
#   0.04917615 -0.03585841 -0.13346473 -0.05208177  0.19407602 -0.16791407
#   0.07349128  0.10001944 -0.1188395  -0.25815577  0.04720243 -0.03438299
#   0.04703867 -0.08065031  0.10008061 -0.01465635 -0.02668778 -0.0390465
#   0.08169717 -0.04228085  0.00416258 -0.07640931  0.07696596  0.03400623
#   0.0425325  -0.16557139 -0.1214525   0.09565798  0.04535675]

# %%
model = LinearRegression()

# %%
X=X.reshape(-1,1)
Y=Y.reshape(-1,1)

# %%
X
# Out:
# array([[-1.  ],
#        [-0.98],
#        [-0.96],
#        [-0.94],
#        [-0.92],
#        [-0.9 ],
#        [-0.88],
#        [-0.86],
#        [-0.84],
#        [-0.82],
#        [-0.8 ],
#        [-0.78],
#        [-0.76],
#        [-0.74],
#        [-0.72],
#        [-0.7 ],
#        [-0.68],
#        [-0.66],
#        [-0.64],
#        [-0.62],
#        [-0.6 ],
#        [-0.58],
#        [-0.56],
#        [-0.54],
#        [-0.52],
#        [-0.5 ],
#        [-0.48],
#        [-0.46],
#        [-0.44],
#        [-0.42],
#        [-0.4 ],
#        [-0.38],
#        [-0.36],
#        [-0.34],
#        [-0.32],
#        [-0.3 ],
#        [-0.28],
#        [-0.26],
#        [-0.24],
#        [-0.22],
#        [-0.2 ],
#        [-0.18],
#        [-0.16],
#        [-0.14],
#        [-0.12],
#        [-0.1 ],
#        [-0.08],
#        [-0.06],
#        [-0.04],
#        [-0.02],
#        [ 0.  ],
#        [ 0.02],
#        [ 0.04],
#        [ 0.06],
#        [ 0.08],
#        [ 0.1 ],
#        [ 0.12],
#        [ 0.14],
#        [ 0.16],
#        [ 0.18],
#        [ 0.2 ],
#        [ 0.22],
#        [ 0.24],
#        [ 0.26],
#        [ 0.28],
#        [ 0.3 ],
#        [ 0.32],
#        [ 0.34],
#        [ 0.36],
#        [ 0.38],
#        [ 0.4 ],
#        [ 0.42],
#        [ 0.44],
#        [ 0.46],
#        [ 0.48],
#        [ 0.5 ],
#        [ 0.52],
#        [ 0.54],
#        [ 0.56],
#        [ 0.58],
#        [ 0.6 ],
#        [ 0.62],
#        [ 0.64],
#        [ 0.66],
#        [ 0.68],
#        [ 0.7 ],
#        [ 0.72],
#        [ 0.74],
#        [ 0.76],
#        [ 0.78],
#        [ 0.8 ],
#        [ 0.82],
#        [ 0.84],
#        [ 0.86],
#        [ 0.88],
#        [ 0.9 ],
#        [ 0.92],
#        [ 0.94],
#        [ 0.96],
#        [ 0.98],
#        [ 1.  ]])

# %%
model.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
m= model.coef_

# %%
c=model.intercept_

# %%
print m,c
# Out:
# [[ 1.98522779]] [-0.00101855]

# %%
plt.plot(X, Y)

plt.plot(X, m * X +c, 'r')

# %%
model.predict(1)
# Out:
# array([[ 1.98420924]])

# %%
model.score(X,Y)
# Out:
# 0.99277442881391953
